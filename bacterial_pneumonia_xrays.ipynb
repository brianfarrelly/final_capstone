# %% [markdown]
# <a href="https://colab.research.google.com/github/brianfarrelly/final_capstone/blob/master/bacterial_pneumonia_xrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd

from google.colab import drive


import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
DATASET_DIR = "/content/gdrive/My Drive/data/corona_normal_bacterial/"

# %%
os.listdir(DATASET_DIR)
# Out:
# ['train', 'test']

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

normal_images = []
for img_path in glob.glob(DATASET_DIR + '/train/normal/*'):
    normal_images.append(mpimg.imread(img_path))
    break

fig = plt.figure()
fig.suptitle('normal')
plt.imshow(normal_images[0], cmap='gray') 

covid_images = []
for img_path in glob.glob(DATASET_DIR + '/train/bacterial/*'):
    covid_images.append(mpimg.imread(img_path))
    break

fig = plt.figure()
fig.suptitle('bacterial pneumonia')
plt.imshow(covid_images[0], cmap='gray')

# %%
IMG_W = 400
IMG_H = 400
CHANNELS = 3

INPUT_SHAPE = (IMG_W, IMG_H, CHANNELS)
NB_CLASSES = 2
EPOCHS = 48
BATCH_SIZE = 6

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(Conv2D(250,(3,3)))
model.add(Activation("relu"))
  
model.add(Conv2D(128,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))
model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))

model.add(Conv2D(256,(2,2)))
model.add(Activation("relu"))
model.add(MaxPool2D(2,2))
    
model.add(Flatten())
model.add(Dense(32))
model.add(Dropout(0.25))

model.add(Dense(2))

#model.add(Dense(1))
#model.add(Activation("sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 398, 398, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 398, 398, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 199, 199, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 197, 197, 32)      9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 197, 197, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 96, 96, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 96, 96, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 94, 94, 250)       144250
# _________________________________________________________________
# activation_4 (Activation)    (None, 94, 94, 250)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 92, 92, 128)       288128
# _________________________________________________________________
# activation_5 (Activation)    (None, 92, 92, 128)       0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 46, 46, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 44, 44, 64)        73792
# _________________________________________________________________
# activation_6 (Activation)    (None, 44, 44, 64)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 21, 21, 256)       65792
# _________________________________________________________________
# activation_7 (Activation)    (None, 21, 21, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25600)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                819232
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 1,419,900
# Trainable params: 1,419,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['mae', 'sparse_categorical_accuracy'])

# %%
DATASET_DIR = "/content/gdrive/My Drive/data/corona_normal_bacterial/"

# %%
print(DATASET_DIR)
# Out:
# /content/gdrive/My Drive/data/corona_normal_bacterial/

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.3)

valid_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.3)

test_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.3)

# %%
train_generator = train_datagen.flow_from_directory(
    #directory=r"/content/gdrive/My Drive/data/corona_normal_bacterial/train/",
    directory=DATASET_DIR + "/train/",
    target_size=(IMG_W, IMG_H),
    color_mode="rgb",
    batch_size=32,
    class_mode="binary",
    shuffle=True,
    seed=42
)

validation_generator = train_datagen.flow_from_directory(
    #directory=r"/content/gdrive/My Drive/data/corona_normal_bacterial/train/",
    directory=DATASET_DIR + "/train/",
    target_size=(IMG_W, IMG_H),
    batch_size=32,
    class_mode='binary',
    shuffle=True,
    subset='validation'
)

test_generator = test_datagen.flow_from_directory(
    #directory=r"/content/gdrive/My Drive/data/corona_normal_bacterial/test/",
    directory=DATASET_DIR + "/test/",
    target_size=(IMG_W, IMG_H),
    color_mode="rgb",
    batch_size=32,
    class_mode='binary',
    shuffle=False,
    seed=42
)
# Out:
# Found 1400 images belonging to 2 classes.
# Found 420 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = 64,
    validation_data = validation_generator, 
    validation_steps = 16,
    epochs = 50)
# Out:
# Epoch 1/50
# 20/64 [========>.....................] - ETA: 13:09 - loss: 0.7247 - mae: 0.6140 - sparse_categorical_accuracy: 0.5538
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py:616: UserWarning: The input 24 could not be retrieved. It could be because a worker has died.
#   UserWarning)
# 64/64 [==============================] - 796s 12s/step - loss: 0.5022 - mae: 1.1656 - sparse_categorical_accuracy: 0.7392 - val_loss: 0.1831 - val_mae: 1.9105 - val_sparse_categorical_accuracy: 0.8967
# Epoch 2/50
# 64/64 [==============================] - 92s 1s/step - loss: 0.2877 - mae: 1.9436 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.4642 - val_mae: 1.9420 - val_sparse_categorical_accuracy: 0.8822
# Epoch 3/50
# 64/64 [==============================] - 95s 1s/step - loss: 0.3198 - mae: 2.1266 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.2880 - val_mae: 2.0668 - val_sparse_categorical_accuracy: 0.9132
# Epoch 4/50
# 64/64 [==============================] - 90s 1s/step - loss: 0.2176 - mae: 2.5816 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.1335 - val_mae: 2.4028 - val_sparse_categorical_accuracy: 0.9339
# Epoch 5/50
# 64/64 [==============================] - 91s 1s/step - loss: 0.1913 - mae: 2.6910 - sparse_categorical_accuracy: 0.9304 - val_loss: 0.1705 - val_mae: 2.4677 - val_sparse_categorical_accuracy: 0.9298
# Epoch 6/50
# 64/64 [==============================] - 88s 1s/step - loss: 0.1625 - mae: 2.4508 - sparse_categorical_accuracy: 0.9444 - val_loss: 0.1385 - val_mae: 2.2251 - val_sparse_categorical_accuracy: 0.9277
# Epoch 7/50
# 64/64 [==============================] - 88s 1s/step - loss: 0.1651 - mae: 2.6941 - sparse_categorical_accuracy: 0.9382 - val_loss: 0.6293 - val_mae: 2.7114 - val_sparse_categorical_accuracy: 0.9408
# Epoch 8/50
# 64/64 [==============================] - 77s 1s/step - loss: 0.1382 - mae: 2.8696 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2532 - val_mae: 2.3681 - val_sparse_categorical_accuracy: 0.9504
# Epoch 9/50
# 64/64 [==============================] - 84s 1s/step - loss: 0.1392 - mae: 2.7684 - sparse_categorical_accuracy: 0.9510 - val_loss: 0.1896 - val_mae: 2.7309 - val_sparse_categorical_accuracy: 0.9504
# Epoch 10/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1417 - mae: 2.7371 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.1462 - val_mae: 3.4116 - val_sparse_categorical_accuracy: 0.9545
# Epoch 11/50
# 64/64 [==============================] - 85s 1s/step - loss: 0.1427 - mae: 2.6005 - sparse_categorical_accuracy: 0.9485 - val_loss: 0.1328 - val_mae: 3.2673 - val_sparse_categorical_accuracy: 0.9298
# Epoch 12/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1156 - mae: 2.9747 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.0302 - val_mae: 2.5729 - val_sparse_categorical_accuracy: 0.9483
# Epoch 13/50
# 64/64 [==============================] - 84s 1s/step - loss: 0.1688 - mae: 2.8832 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.2682 - val_mae: 1.8047 - val_sparse_categorical_accuracy: 0.8781
# Epoch 14/50
# 64/64 [==============================] - 97s 2s/step - loss: 0.1592 - mae: 2.8033 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.1041 - val_mae: 3.2921 - val_sparse_categorical_accuracy: 0.9518
# Epoch 15/50
# 64/64 [==============================] - 80s 1s/step - loss: 0.1264 - mae: 3.0126 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.2821 - val_mae: 2.9589 - val_sparse_categorical_accuracy: 0.9607
# Epoch 16/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1264 - mae: 2.9625 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.2332 - val_mae: 2.9031 - val_sparse_categorical_accuracy: 0.9504
# Epoch 17/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.1241 - mae: 2.8483 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.2260 - val_mae: 2.6295 - val_sparse_categorical_accuracy: 0.9587
# Epoch 18/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1193 - mae: 2.9091 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.2778 - val_mae: 2.2893 - val_sparse_categorical_accuracy: 0.9566
# Epoch 19/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1019 - mae: 2.9557 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.0415 - val_mae: 3.1823 - val_sparse_categorical_accuracy: 0.9442
# Epoch 20/50
# 64/64 [==============================] - 85s 1s/step - loss: 0.1014 - mae: 3.2816 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1262 - val_mae: 1.7890 - val_sparse_categorical_accuracy: 0.9442
# Epoch 21/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.1249 - mae: 2.9480 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.0101 - val_mae: 3.3636 - val_sparse_categorical_accuracy: 0.9452
# Epoch 22/50
# 64/64 [==============================] - 76s 1s/step - loss: 0.1191 - mae: 3.2325 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.2662 - val_mae: 3.4500 - val_sparse_categorical_accuracy: 0.9607
# Epoch 23/50
# 64/64 [==============================] - 84s 1s/step - loss: 0.1213 - mae: 3.4412 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.1092 - val_mae: 3.2658 - val_sparse_categorical_accuracy: 0.9587
# Epoch 24/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.1027 - mae: 3.4033 - sparse_categorical_accuracy: 0.9627 - val_loss: 0.3717 - val_mae: 3.6498 - val_sparse_categorical_accuracy: 0.9628
# Epoch 25/50
# 64/64 [==============================] - 90s 1s/step - loss: 0.1071 - mae: 3.2488 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.0574 - val_mae: 3.5217 - val_sparse_categorical_accuracy: 0.9587
# Epoch 26/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.0978 - mae: 3.3931 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1231 - val_mae: 2.6690 - val_sparse_categorical_accuracy: 0.9401
# Epoch 27/50
# 64/64 [==============================] - 88s 1s/step - loss: 0.0904 - mae: 3.6446 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.2117 - val_mae: 4.5956 - val_sparse_categorical_accuracy: 0.9628
# Epoch 28/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.0832 - mae: 4.9506 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.0947 - val_mae: 4.7090 - val_sparse_categorical_accuracy: 0.9693
# Epoch 29/50
# 64/64 [==============================] - 76s 1s/step - loss: 0.0965 - mae: 3.8187 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.0683 - val_mae: 3.6187 - val_sparse_categorical_accuracy: 0.9607
# Epoch 30/50
# 64/64 [==============================] - 84s 1s/step - loss: 0.1037 - mae: 3.7299 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.2355 - val_mae: 3.2010 - val_sparse_categorical_accuracy: 0.9628
# Epoch 31/50
# 64/64 [==============================] - 85s 1s/step - loss: 0.0857 - mae: 3.4264 - sparse_categorical_accuracy: 0.9721 - val_loss: 0.0756 - val_mae: 2.5439 - val_sparse_categorical_accuracy: 0.9545
# Epoch 32/50
# 64/64 [==============================] - 86s 1s/step - loss: 0.0856 - mae: 3.2640 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.0624 - val_mae: 3.8801 - val_sparse_categorical_accuracy: 0.9690
# Epoch 33/50
# 64/64 [==============================] - 88s 1s/step - loss: 0.1130 - mae: 3.5677 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.2407 - val_mae: 3.1172 - val_sparse_categorical_accuracy: 0.9504
# Epoch 34/50
# 64/64 [==============================] - 91s 1s/step - loss: 0.0966 - mae: 3.3231 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.0873 - val_mae: 2.4971 - val_sparse_categorical_accuracy: 0.9566
# Epoch 35/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.0698 - mae: 3.7155 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0101 - val_mae: 3.2358 - val_sparse_categorical_accuracy: 0.9452
# Epoch 36/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.0885 - mae: 3.4927 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.0284 - val_mae: 3.8577 - val_sparse_categorical_accuracy: 0.9773
# Epoch 37/50
# 64/64 [==============================] - 88s 1s/step - loss: 0.0785 - mae: 3.9241 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0370 - val_mae: 3.0289 - val_sparse_categorical_accuracy: 0.9793
# Epoch 38/50
# 64/64 [==============================] - 92s 1s/step - loss: 0.0825 - mae: 3.6151 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.0176 - val_mae: 4.2588 - val_sparse_categorical_accuracy: 0.9752
# Epoch 39/50
# 64/64 [==============================] - 92s 1s/step - loss: 0.0958 - mae: 3.5427 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.1557 - val_mae: 2.7915 - val_sparse_categorical_accuracy: 0.9835
# Epoch 40/50
# 64/64 [==============================] - 93s 1s/step - loss: 0.0687 - mae: 3.6116 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.0022 - val_mae: 3.8031 - val_sparse_categorical_accuracy: 0.9793
# Epoch 41/50
# 64/64 [==============================] - 94s 1s/step - loss: 0.0791 - mae: 3.6923 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.1305 - val_mae: 3.4421 - val_sparse_categorical_accuracy: 0.9773
# Epoch 42/50
# 64/64 [==============================] - 93s 1s/step - loss: 0.0649 - mae: 3.7141 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.0078 - val_mae: 3.6406 - val_sparse_categorical_accuracy: 0.9649
# Epoch 43/50
# 64/64 [==============================] - 82s 1s/step - loss: 0.0799 - mae: 4.0368 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0869 - val_mae: 3.1002 - val_sparse_categorical_accuracy: 0.9669
# Epoch 44/50
# 64/64 [==============================] - 89s 1s/step - loss: 0.0663 - mae: 3.7869 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0284 - val_mae: 4.1952 - val_sparse_categorical_accuracy: 0.9814
# Epoch 45/50
# 64/64 [==============================] - 90s 1s/step - loss: 0.0725 - mae: 3.9082 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.0551 - val_mae: 3.3419 - val_sparse_categorical_accuracy: 0.9711
# Epoch 46/50
# 64/64 [==============================] - 89s 1s/step - loss: 0.0645 - mae: 4.0813 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.0400 - val_mae: 3.3700 - val_sparse_categorical_accuracy: 0.9835
# Epoch 47/50
# 64/64 [==============================] - 95s 1s/step - loss: 0.0674 - mae: 4.1455 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.1739 - val_mae: 3.6763 - val_sparse_categorical_accuracy: 0.9773
# Epoch 48/50
# 64/64 [==============================] - 87s 1s/step - loss: 0.0682 - mae: 3.7847 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0361 - val_mae: 5.1366 - val_sparse_categorical_accuracy: 0.9711
# Epoch 49/50
# 64/64 [==============================] - 92s 1s/step - loss: 0.0706 - mae: 3.8775 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0025 - val_mae: 3.5472 - val_sparse_categorical_accuracy: 0.9846
# Epoch 50/50
# 64/64 [==============================] - 76s 1s/step - loss: 0.0606 - mae: 4.1883 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.1486 - val_mae: 5.1248 - val_sparse_categorical_accuracy: 0.9731

# %%
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('model categorical accuracy')
plt.ylabel('categorical accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import seaborn as sns
import matplotlib.pyplot as plt

Y_pred = model.predict_generator(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

#print(y_pred)

#print('Confusion Matrix')
#print(confusion_matrix(test_generator.classes, y_pred))

print(" ")
print(" ")
print(" ")


print('Classification Report')
target_names = ['Normal', 'Bacterial']

print(classification_report(test_generator.classes, y_pred, target_names=target_names))

print(" ")
print(" ")
print(" ")

#print(test_generator.classes)

cm = confusion_matrix(test_generator.classes, y_pred)

sns.heatmap(cm, cmap='Blues', annot=True)
# Out:
#
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.94      0.92       200
#    Bacterial       0.94      0.90      0.92       200
#
#     accuracy                           0.92       400
#    macro avg       0.92      0.92      0.92       400
# weighted avg       0.92      0.92      0.92       400

# %%
print(DATASET_DIR)
# Out:
# /content/gdrive/My Drive/data/corona_normal_bacterial/

# %%
# evaluate the model
scores = model.evaluate(test_generator, verbose=1)
# Out:
# 13/13 [==============================] - 16s 1s/step

# %%
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f" % (model.metrics_names[1], scores[1]))
print("%s: %.2f" % (model.metrics_names[2], scores[2]))
# Out:
# loss: 0.41
# mae: 4.43
# sparse_categorical_accuracy: 0.92

# %%
# save model and architecture to single file
model.save(DATASET_DIR+ "/bacmodel.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
